# %% [markdown]
# Original Opensees Example Link: https://opensees.berkeley.edu/wiki/index.php/OpenSees_Example_4._Portal_Frame
#
# <img src="https://opensees.berkeley.edu/wiki/images/e/e0/Example4_figure1.GIF" align="left"></img>
# <img src="https://opensees.berkeley.edu/wiki/images/5/59/Example1b_Push.GIF" align="right"></img>

# %%
import openseespy.opensees as ops
import opsvis as ovs
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Units Conversion

# %%
#length conversion
m = 1.0
cm = 100*m # centimeter, needed for displacement input in MultipleSupport excitation
inch = m/39.37
ft = 12.*inch 

#area conversion
sqinch = inch**2
inch4 = inch**4

#ksi to pa
pa = 1.0
kpa = 1000*pa
ksi = 6.89*1000*kpa  #ksi = kip / sqinch
psi = ksi/1000.


#kip to kN
N = 1.0
kN = 1000 * N
kip = 4.45 * kN

# pound to kg
kg = 1 
pound = 0.453592 * kg
lbf = psi*inch**2  #pounds force
pcf = lbf/math.pow(ft, 3) #pounds per cubic foot
psf = lbf/math.pow(ft, 2) #pounds per square foot


# acceleration due to gravity
g = 9.81 #m/s^2

#time
sec = 1.0

# %% [markdown]
# ## Model Varibles for Elastic Element Section

# %%
#refrences taken from elastic model in original example 
sectionType = 'elastic'  #this analysis uses elastic section of beam and column

#Structure Geometry
LCol = 36.*ft		# column length
LBeam = 42.*ft		# beam length
Weight = 4000.*kip		# superstructure weight #total imposed load on the beam in kN or Kip


#section general geometry
HCol = 5.*ft #depth of column
BCol = 4.*ft #width of column
HBeam = 8.*ft #depth of beam
BBeam = 5.*ft #width of beam

# calculated parameters
PCol = Weight/2 #nodal dead weight per column
Mass = PCol/g #nodal mass
MCol = 1./12.* (Weight/LBeam) *math.pow(LBeam,2)	# beam-end moment due to distributed load.        #wl^2/12


#calculated geometry parameters
ACol = BCol * HCol
ABeam = BBeam * HBeam
IzCol = 1./12. * BCol * math.pow(HCol, 3)
IzBeam = 1./12. * BBeam * math.pow(HBeam, 3)

# %% [markdown]
# ## Model Functions

# %%
def getModel():
    ops.wipe()
    ops.model("BasicBuilder", '-ndm', 2, '-ndf', 3)

    #nodes definition
    xcor = [0, LBeam]
    ycor = [0, LCol]
    for j,y in enumerate(ycor):
        for i,x in enumerate(xcor):
            ops.node(j*len(xcor)+i + 1, *[x,y])
    
    #fixity definition
    ops.fixY(0, *[1,1,1]) #fix all nodes with ycoordinate = 0 (so fixing both node 1 and 2: base nodes)

    # nodal masses:
    ops.mass(3, *[Mass, 0., 0.])	# node#, Mx My Mz, Mass=Weight/g, neglect rotational inertia at nodes
    ops.mass(4, *[Mass, 0., 0.])

# %%
def getSections(plotFiber = True):
    #section tags identifiers
    colSecTag = 1
    beamSecTag = 2
    
    #section Geometry
    coverCol = 6.*inch		# Column cover to reinforcing steel NA.
    numBarsCol = 10	# number of longitudinal-reinforcement bars in each side of column section. (symmetric top & bot)
    barAreaCol = 2.25*sqinch	# area of longitudinal-reinforcement bars

    # MATERIAL parameters -------------------------------------------------------------------
    IDconcU = 1 			# material ID tag -- unconfined cover concrete
    IDreinf = 2 				# material ID tag -- reinforcement
    
    #material properties
    fc = -4. * ksi # CONCRETE Compressive Strength (+Tension, -Compression)
    Ec = 57 * ksi * math.sqrt(-fc/psi) # Concrete Elastic Modulus

    # unconfined concrete
    fc1U = fc		# UNCONFINED concrete (todeschini parabolic model), maximum stress
    eps1U = -0.003		# strain at maximum strength of unconfined concrete
    fc2U = 0.2*fc1U		# ultimate stress
    eps2U = -0.05;			# strain at ultimate stress
    lambda_ = 0.1;				# ratio between unloading slope at $eps2 and initial slope $Ec

    # tensile-strength properties
    ftU = -0.14*fc1U		# tensile strength +tension
    Ets = ftU/0.002		# tension softening stiffness
    # -----------
    Fy = 66.8*ksi		# STEEL yield stress
    Es = 29000.*ksi	# modulus of steel
    Bs = 0.01			# strain-hardening ratio 
    R0 = 18				# control the transition from elastic to plastic branches
    cR1=  0.925			# control the transition from elastic to plastic branches
    cR2=  0.15				# control the transition from elastic to plastic branches

    ops.uniaxialMaterial('Concrete02', IDconcU, fc1U, eps1U, fc2U, eps2U, lambda_, ftU, Ets)	# build cover concrete (unconfined)
    ops.uniaxialMaterial('Steel02', IDreinf, Fy, Es, Bs, R0, cR1, cR2)			# build reinforcement material

    #section properties
    #Column Section
    coverY = HCol/2.0	# The distance from the section z-axis to the edge of the cover concrete -- outer edge of cover concrete
    coverZ = BCol/2.0	# The distance from the section y-axis to the edge of the cover concrete -- outer edge of cover concrete
    coreY = coverY-coverCol
    coreZ = coverZ-coverCol
    nfY = 16			# number of fibers for concrete in y-direction
    nfZ = 4 	# number of fibers for concrete in z-direction

    ops.section('Fiber', colSecTag)	# Define the fiber section
    ops.patch('quadr', IDconcU, nfZ, nfY, *[-coverY, coverZ, -coverY, -coverZ, coverY, -coverZ, coverY, coverZ]) 	# Define the concrete patch
    ops.layer('straight', IDreinf, numBarsCol, barAreaCol, *[-coreY, coreZ, -coreY, -coreZ])	# top layer reinfocement
    ops.layer('straight', IDreinf, numBarsCol, barAreaCol, *[coreY, coreZ,  coreY, -coreZ])	# bottom layer reinforcement
    # end of fibersection definition

    #Beam Section - Elastic
    ops.section('Elastic', beamSecTag, Ec, ABeam, IzBeam)

    #elements
    colTransfTag = 1
    beamTransfTag = 2
    colTransfType = 'Linear'  #making this variable to help easy change of linear to pdelta, as only column have pdelta effects
    ops.geomTransf(colTransfType, colTransfTag)
    ops.geomTransf('Linear', beamTransfTag)

    
    #element define
    #element('nonlinearBeamColumn', eleTag, *eleNodes, numIntgrPts, secTag, transfTag, '-iter', maxIter=10, tol=1e-12, '-mass', mass=0.0, '-integration', intType)
    numIntgrPts = 5

    ops.element('nonlinearBeamColumn', 1, *[1,3], numIntgrPts, colSecTag, colTransfTag)
    ops.element('nonlinearBeamColumn', 2, *[2,4], numIntgrPts, colSecTag, colTransfTag)
    ops.element('nonlinearBeamColumn', 3, *[3,4], numIntgrPts, beamSecTag, beamTransfTag)

    if plotFiber:
        fibSecList = [['section', 'Fiber', colSecTag],	# Define the fiber section
        ['patch', 'quadr', IDconcU, nfZ, nfY, *[-coverY, coverZ, -coverY, -coverZ, coverY, -coverZ, coverY, coverZ]],	# Define the concrete patch
        ['layer', 'straight', IDreinf, numBarsCol, barAreaCol, *[-coreY, coreZ, -coreY, -coreZ]],	# top layer reinfocement
        ['layer', 'straight', IDreinf, numBarsCol, barAreaCol, *[coreY, coreZ,  coreY, -coreZ]]# bottom layer reinforcement
                     ]
        matcolor = ['lightgrey', 'lightgrey', 'gold', 'w', 'w', 'w']
        ovs.plot_fiber_section(fibSecList ,matcolor=matcolor)
        plt.axis('equal')
        plt.title("Fiber Section of Column")

# %% [markdown]
# ## Recorder Functions

# %%
def getRecorders(SectionType, AnalyisName):
    ops.recorder("Node", '-file', f"Outputs/{SectionType}/{AnalyisName}/DispFree.txt", 
                 '-time', '-closeOnWrite', '-node', *[3,4],'-dof', *[1,2,3], 'disp')
    ops.recorder("Node", '-file', f"Outputs/{SectionType}/{AnalyisName}/DispSupport.txt", 
                 '-time', '-closeOnWrite', '-node', *[1,2],'-dof', *[1,2,3], 'disp')
    ops.recorder("Node", '-file', f"Outputs/{SectionType}/{AnalyisName}/ReactionsSupport.txt", 
                 '-time', '-closeOnWrite', '-node', *[1,2],'-dof', *[1,2,3], 'reaction')

    #drift recorder: but throws error in openseespy
    #ops.recorder("drift", '-file', f"Outputs/{SectionType}/{AnalyisName}_Drift.txt", '-time', '-closeOnWrite', '-inode', *[1,2],'-jnode', *[3,4], '-dof', 1, '-perpDirn', 2)
    
    #recorder Element -file Data/FCol.out -time -ele 1 force
    ops.recorder('Element', '-file', f'Outputs/{SectionType}/{AnalyisName}/ForcesColumn.txt', 
                 '-time', '-closeOnWrite', '-ele', *[1,2], 'globalForce')
    ops.recorder('Element', '-file', f'Outputs/{SectionType}/{AnalyisName}/ForcesBeam.txt', 
                 '-time', '-closeOnWrite', '-ele', 3, 'globalForce')				# Column section forces, axial and moment, node i

# %% [markdown]
# ## Analysis Functions

# %%
linTS = 1 #linear time series tag
sineSeries = 2 #uniform excitation tag

# %% [markdown]
# ### Gravity Analysis

# %%
## Analysis Definitions
def runGravityAnalysis():
    udlBeam = Weight/LBeam
    #gravity loads

    ops.timeSeries('Linear', linTS)
    ops.pattern('Plain', 100, linTS) #patterntype #patterntag #timeseries tag
    ops.eleLoad('-ele', 3, '-type', '-beamUniform', -1* udlBeam)


    #setting gravity analysis parameters and functions
    ops.constraints('Plain')
    ops.numberer('Plain')
    ops.system('BandGeneral')
    
    tol = 1.0e-8
    numIter = 6
    ops.test('NormDispIncr', tol, numIter) #test NormDispIncr $tol $iter <$pFlag> <$nType>
    ops.algorithm('Newton')

    NStepGravity = 10
    DGravity = 1.0 / NStepGravity
    ops.integrator('LoadControl', DGravity)
    ops.analysis('Static')

    ops.record() #to force recorder to record initial state of the model regarding gravity loads
    ops.analyze(NStepGravity)

    #since static pushover is performed after gravity analysis--- set gravity load constant and time to 0
    ops.loadConst('-time', 0.)

# %% [markdown]
# ### Static Pushover

# %%
def runStaticPushover():
    #since static pushover is performed after gravity analysis--- set gravity load constant and time to 0
    ops.loadConst('-time', 0)
    
    #structure parameters
    ControlNode = 3
    ControlNodeDof = 1
    
    #analysis parameters
    Dmax = .1*LCol # maximum displacement of pushover. push to 10% drift.
    Dincr = 0.001*LCol  #increment in displacement for pushover
    NStepPushover = int(Dmax/Dincr)
    
    #incase we want to change test type due to convergence failure
    testTypeStatic = 'EnergyIncr'
    algorithmTypeStatic = 'Newton'
    
    tolStatic = 1.0e-11  
    maxNumIterStatic = 100
    maxNumIterConvergeStatic = 2000 # for improved-convergence procedure
    
    # define the lateral load as a proportion of the weight so that the pseudo time equals the lateral-load coefficient when using linear load pattern
    Hload = Weight/2
    ops.pattern('Plain', 200, linTS) #patterntype #patterntag #timeseries tag
    ops.load(3, *[Hload, 0., 0.])
    ops.load(4, *[Hload, 0., 0.])
    
    #setting gravity analysis parameters and functions
    ops.constraints('Plain')
    ops.numberer('RCM')
    ops.system('BandGeneral')
    
    ops.test(testTypeStatic, tolStatic, maxNumIterStatic) #test NormDispIncr $tol $iter <$pFlag> <$nType>
    ops.algorithm(algorithmTypeStatic)
    
    ops.integrator('DisplacementControl', ControlNode, ControlNodeDof, Dincr)
    ops.analysis('Static')

    ops.record() #to force recorder to record initial state of the model regarding gravity loads
    i = 0
    while ops.nodeDisp(ControlNode, ControlNodeDof) < Dmax:
        status = ops.analyze(1)
        i += 1
        #handling well if the analysis fails:
        if status != 0:
            print("Analysis failed at load factor ", i)
            if status != 0:
                print("Trying Newton with Initial Tangent at Load Factor", i)
                ops.test('NormDispIncr', tolStatic, 2000)
                ops.algorithm('Newton', '-initial')
                status = ops.analyze(1)
                ops.test(testTypeStatic, tolStatic, maxNumIterStatic)
                
            if status !=0:
                print("Trying Bryoden at Load Factor", i)
                ops.algorithm('Bryoden', 8)
                status = ops.analyze(1)
                ops.algorithm(algorithmTypeStatic)
                
            if status !=0:
                print("Trying Newton with Line Search at Load Factor", i)
                ops.algorithm('NewtonLineSearch', 0.8)
                status = ops.analyze(1)
                ops.algorithm(algorithmTypeStatic)
            if status != 0:
                print("Analysis Failed, exiting")
                break
                
    if status != 0:
        print(f"Problem! Pushover Analysis\t Node={ControlNode}, Dof={ControlNodeDof}, Disp={ops.nodeDisp(ControlNode, ControlNodeDof)}")
    else:
        print(f"Success! Pushover Analysis\t Node={ControlNode}, Dof={ControlNodeDof}, Disp={ops.nodeDisp(ControlNode, ControlNodeDof)}")

# %% [markdown]
# ### Reverse Cyclic Pushover

# %%
def generatePeaks(Dmax, DincrStatic = 0.01, cycleType = 'Full', Factor = 1.0):
    """
    To return array of displacement for Push/Half/Full cycle
    """
    D0 = 0.0
    Dmax = Dmax * Factor
    Disps = [D0]
    if Dmax < 0:
        dx = -DincrStatic
    elif Dmax > 0:
        dx = DincrStatic

    Nsteps = int(abs(Dmax/DincrStatic))

    for i in range(Nsteps): #zero displacement to peak displacement (in any direction)
        D0 += dx
        Disps.append(D0)

    if cycleType != 'Push': #now there is chance of cycle type being full cycle or half cycle
        for i in range(Nsteps): #half cycle
            D0 -= dx #return displacement from peak to 0
            Disps.append(D0)
        
        if cycleType != 'Half': #it must be full cycle by now
            for i in range(Nsteps): #0 to negative peak
                D0 -= dx
                Disps.append(D0)

            for i in range(Nsteps): #negative peak to zero
                D0 += dx
                Disps.append(D0)
                
    return np.array(Disps)

# %%
def runReverseCyclicPushover(Ncycles = 1, cycleType = "Full", plotPeaks = True):
    #structure parameters
    ControlNode = 3
    ControlNodeDof = 1

    #analysis parameters
    Dmaxs = np.array([0.005, 0.01, 0.035, 0.1]) # maximum displacement of pushover. push to 10% drift.
    Dincr = 0.001*LCol  #increment in displacement for pushover
    print(LCol, Dincr)
    Fact = LCol				# scale drift ratio by storey height for displacement cycles
    
    # define the lateral load as a proportion of the weight so that the pseudo time equals the lateral-load coefficient when using linear load pattern
    Hload = Weight/2
    ops.pattern('Plain', 300, linTS) #patterntype #patterntag #timeseries tag
    ops.load(3, *[Hload, 0., 0.])
    ops.load(4, *[Hload, 0., 0.])
            
    #incase we want to change test type due to convergence failure
    testTypeStatic = 'EnergyIncr'
    algorithmTypeStatic = 'Newton'
    
    tolStatic = 1.0e-11
    maxNumIterStatic = 100
    maxNumIterConvergeStatic = 2000 # for improved-convergence procedure
    
    #setting gravity analysis parameters and functions
    ops.constraints('Plain')
    ops.numberer('RCM')
    ops.system('BandGeneral')
    
    ops.test(testTypeStatic, tolStatic, maxNumIterStatic) #test NormDispIncr $tol $iter <$pFlag> <$nType>
    ops.algorithm(algorithmTypeStatic)
    
    for dMax  in Dmaxs:
        DSteps = generatePeaks(dMax, DincrStatic=Dincr, cycleType='Full', Factor=Fact)
        
        for i in range(Ncycles):
            D0 = 0.
            for DStep in DSteps:
                D1 = DStep
                Dincr = D1 - D0
                ops.integrator('DisplacementControl', ControlNode, ControlNodeDof, Dincr)
                ops.analysis('Static')

                status = ops.analyze(1)

                #handling well if the analysis fails:
                if status != 0:
                    print("Analysis Failed ! Trying other methods ...")
                    if status != 0:
                        print("Trying Newton with Initial Tangent")
                        ops.test('NormDispIncr', tolStatic, 2000)
                        ops.algorithm('Newton', '-initial')
                        status = ops.analyze(1)
                        ops.test(testTypeStatic, tolStatic, maxNumIterStatic)
                        ops.algorithm(algorithmTypeStatic)
                        
                    if status !=0:
                        print("Trying Bryoden")
                        ops.algorithm('Bryoden', 8)
                        status = ops.analyze(1)
                        ops.algorithm(algorithmTypeStatic)
                        
                    if status !=0:
                        print("Trying Newton with Line Search")
                        ops.algorithm('NewtonLineSearch', 0.8)
                        status = ops.analyze(1)
                        ops.algorithm(algorithmTypeStatic)

                    if status != 0:
                        print("Failed ! Terminating Analysis")
                        return 
                D0 = D1
    if status != 0:
        print(f"Problem! Cyclic Pushover Analysis\t Node={ControlNode}, Dof={ControlNodeDof}, Disp={ops.nodeDisp(ControlNode, ControlNodeDof)}")
    else:
        print(f"Success! Cyclic Pushover Analysis\t Node={ControlNode}, Dof={ControlNodeDof}, Disp={ops.nodeDisp(ControlNode, ControlNodeDof)}")

# %% [markdown]
# ### Dynamic Uniform Sinewave ground motion

# %%
# set up ground motion analysis parameters
DtAnalysis = 0.01*sec
TmaxAnalysis = 10.*sec

#some other dynamic analysis variables
algorithmTypeDynamic = 'ModifiedNewton'
integratorTypeDynamic = 'Newmark'
NewmarkGamma = 0.5
NewmarkBeta = 0.25

testTypeDynamic = 'EnergyIncr'
tolDynamic = 1.0e-8
maxNumIterDynamic = 10
maxNumIterConvergeDynamic = 2000


def runUniformSineWaveGM():
    ops.loadConst('-time', 0)
    
    ops.constraints('Transformation')
    ops.numberer('RCM')
    ops.system('BandGeneral')
    ops.test(testTypeDynamic, tolDynamic, maxNumIterDynamic)
    ops.algorithm(algorithmTypeDynamic)
    ops.integrator(integratorTypeDynamic, NewmarkGamma, NewmarkBeta)
    ops.analysis('Transient')
    
    # define Rayleigh Damping
    xDamp = 0.2  #2% damping ratio
    lambda_ = ops.eigen(1)
    omega = math.pow(lambda_[0], 0.5)
    alphaM = 0.
    betaKcurr = 0.
    betaKcomm = 2.*xDamp/omega
    betaKinit = 0.
    ops.rayleigh(alphaM, betaKcurr, betaKinit, betaKcomm)  #rayleigh damping
    
    #perform dynamic ground motion analysis
    # Uniform Sine-Wave ground motion (uniform acceleration input at all support nodes)
    GMdirection = 1
    GMSineAccAmpl = 0.5*g
    TPeriodSine = .35*sec
    DurationSine = 3.0*sec
    #pattern('UniformExcitation', patternTag, dir, '-disp', dispSeriesTag, '-vel', velSeriesTag, '-accel', accelSeriesTag, '-vel0', vel0, '-fact', fact)
    patternTag = 400
    DtGround = 0.005*sec
    omegaSine = 2*np.pi/TPeriodSine
    vel0 = GMSineAccAmpl*(-1)/omegaSine
    ops.timeSeries('Trig',sineSeries, 0, DurationSine, TPeriodSine, '-factor', GMSineAccAmpl)
    ops.pattern('UniformExcitation', patternTag, GMdirection, '-accel', sineSeries, '-vel0', vel0)

    Nsteps = int(TmaxAnalysis/DtAnalysis)
    status = ops.analyze(Nsteps, DtAnalysis)

# %% [markdown]
# ## Analyses

# %% [markdown]
# #### Gravity Analysis

# %%
getModel()
getSections()
getRecorders('fiberSection', 'GravityAnalysis')
runGravityAnalysis()

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ovs.plot_loads_2d(ax = ax[0])
ovs.plot_defo(ax=ax[1])
ax[0].set_title("Loads")
ax[1].set_title("Deformation")
plt.suptitle("GravityAnalysis")
# Out:
# Text(0.5, 0.98, 'GravityAnalysis')

# %% [markdown]
# #### Static Pushover

# %%
getModel()
getSections()
runGravityAnalysis()
getRecorders('fiberSection', 'StaticPushover')
runStaticPushover()
# Out:
# WARNING can't set handler after analysis is created
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 59.1507 (max: 1e-11) 	Norm deltaX: 0.000310593, Norm deltaR: 546990
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.301959
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.34911e-05 (max: 1e-11) 	Norm deltaX: 8.7409e-08, Norm deltaR: 308.726
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.307439
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 3.21074e-11 (max: 1e-11) 	Norm deltaX: 1.41774e-10, Norm deltaR: 0.460463
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.304343
# OpenSees > analyze failed, returned: -3 error flag
# Analysis failed at load factor  43
# Trying Newton with Initial Tangent at Load Factor 43
# Analysis failed at load factor  47
# Trying Newton with Initial Tangent at Load Factor 47
# Analysis failed at load factor  48
# Trying Newton with Initial Tangent at Load Factor 48
# Analysis failed at load factor  51
# Trying Newton with Initial Tangent at Load Factor 51
# Analysis failed at load factor  52
# Trying Newton with Initial Tangent at Load Factor 52
# Analysis failed at load factor  53
# Trying Newton with Initial Tangent at Load Factor 53
# Analysis failed at load factor  59
# Trying Newton with Initial Tangent at Load Factor 59
# Analysis failed at load factor  60
# Trying Newton with Initial Tangent at Load Factor 60
# Analysis failed at load factor  61
# Trying Newton with Initial Tangent at Load Factor 61
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.42539e-11 (max: 1e-11) 	Norm deltaX: 9.35445e-11, Norm deltaR: 0.304787
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.307063
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 7.77441e-08 (max: 1e-11) 	Norm deltaX: 6.92457e-09, Norm deltaR: 22.6571
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.305031
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 9.72484e-10 (max: 1e-11) 	Norm deltaX: 7.58172e-10, Norm deltaR: 2.56995
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.300819
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.9118e-10 (max: 1e-11) 	Norm deltaX: 3.43398e-10, Norm deltaR: 1.11359
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.300827
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 4.11988e-08 (max: 1e-11) 	Norm deltaX: 4.92472e-09, Norm deltaR: 16.7334
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.301191
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 6.05386e-06 (max: 1e-11) 	Norm deltaX: 5.93002e-08, Norm deltaR: 204.252
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.299652
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 4.11821e-10 (max: 1e-11) 	Norm deltaX: 5.11984e-10, Norm deltaR: 1.61211
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.285344
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.55498e-08 (max: 1e-11) 	Norm deltaX: 3.02607e-09, Norm deltaR: 10.2788
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.296233
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 4.87099e-05 (max: 1e-11) 	Norm deltaX: 1.71498e-07, Norm deltaR: 575.21
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.292954
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 6.84112e-05 (max: 1e-11) 	Norm deltaX: 1.95977e-07, Norm deltaR: 698.623
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.286742
# OpenSees > analyze failed, returned: -3 error flag
# Analysis failed at load factor  66
# Trying Newton with Initial Tangent at Load Factor 66
# Analysis failed at load factor  73
# Trying Newton with Initial Tangent at Load Factor 73
# Analysis failed at load factor  74
# Trying Newton with Initial Tangent at Load Factor 74
# Analysis failed at load factor  77
# Trying Newton with Initial Tangent at Load Factor 77
# Analysis failed at load factor  79
# Trying Newton with Initial Tangent at Load Factor 79
# Analysis failed at load factor  87
# Trying Newton with Initial Tangent at Load Factor 87
# Analysis failed at load factor  88
# Trying Newton with Initial Tangent at Load Factor 88
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.79109e-09 (max: 1e-11) 	Norm deltaX: 1.03976e-09, Norm deltaR: 3.44691
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.287392
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 3.44988e-07 (max: 1e-11) 	Norm deltaX: 1.43045e-08, Norm deltaR: 48.2444
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.289664
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.81472e-08 (max: 1e-11) 	Norm deltaX: 3.34529e-09, Norm deltaR: 11.0097
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.289238
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.40709e-11 (max: 1e-11) 	Norm deltaX: 9.23203e-11, Norm deltaR: 0.304923
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.293844
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.000279101 (max: 1e-11) 	Norm deltaX: 3.92486e-07, Norm deltaR: 1422.51
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.294455
# OpenSees > analyze failed, returned: -3 error flag
# Analysis failed at load factor  97
# Trying Newton with Initial Tangent at Load Factor 97
# Analysis failed at load factor  98
# Trying Newton with Initial Tangent at Load Factor 98
# Success! Pushover Analysis	 Node=3, Dof=1, Disp=1.0973350031816491

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ovs.plot_loads_2d(ax = ax[0])
ovs.plot_defo(ax=ax[1])
ax[0].set_title("Loads")
ax[1].set_title("Deformation")
plt.suptitle("Static Pushover Analysis")
# Out:
# Text(0.5, 0.98, 'Static Pushover Analysis')

# %%
disps = np.loadtxt('Outputs/fiberSection/StaticPushover/DispFree.txt')
rxns = np.loadtxt('Outputs/fiberSection/StaticPushover/ReactionsSupport.txt')
plt.plot(disps[:, 1]/inch, -rxns[:,1]/kip)
plt.grid()
plt.xticks(list(range(0, 50, 5)))
plt.xlim((0, 50))
#plt.ylim((0, 800))
plt.xlabel("Relative Lateral Displacement (inch)")
plt.ylabel("Base Shear (kip)")
plt.title("Force Deformation Response - Static Pushover")
# Out:
# Text(0.5, 1.0, 'Force Deformation Response - Static Pushover')

# %% [markdown]
# #### Reverse Cyclic Pushover

# %%
getModel()
getSections()
runGravityAnalysis()
getRecorders('fiberSection', 'CyclicPushover')
runReverseCyclicPushover(1)
# Out:
# 10.972821945643894 0.010972821945643894
# WARNING can't set handler after analysis is created
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 13.0591 (max: 1e-11) 	Norm deltaX: 0.000337793, Norm deltaR: 83192.5
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.292976
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.818912 (max: 1e-11) 	Norm deltaX: 6.01173e-05, Norm deltaR: 30438.8
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.300061
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 27.4073 (max: 1e-11) 	Norm deltaX: 0.000327886, Norm deltaR: 174229
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.300769
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 2.22052 (max: 1e-11) 	Norm deltaX: 0.000132421, Norm deltaR: 37076.7
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.303016
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 5.85248 (max: 1e-11) 	Norm deltaX: 0.000160974, Norm deltaR: 79562.1
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.304853
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 43.3071 (max: 1e-11) 	Norm deltaX: 0.000419213, Norm deltaR: 208610
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.299854
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 10.5604 (max: 1e-11) 	Norm deltaX: 0.000236021, Norm deltaR: 96019.3
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.29092
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 84.7682 (max: 1e-11) 	Norm deltaX: 0.000695998, Norm deltaR: 257352
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.288277
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 30.4427 (max: 1e-11) 	Norm deltaX: 0.000225704, Norm deltaR: 281994
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.290833
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 86.8371 (max: 1e-11) 	Norm deltaX: 0.000709135, Norm deltaR: 258237
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.285665
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 6.30193 (max: 1e-11) 	Norm deltaX: 0.000229971, Norm deltaR: 55359.3
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.29307
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 2.81672 (max: 1e-11) 	Norm deltaX: 0.000134662, Norm deltaR: 44617.7
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.0963792
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 14.8755 (max: 1e-11) 	Norm deltaX: 0.000245873, Norm deltaR: 130177
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.297727
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.384035 (max: 1e-11) 	Norm deltaX: 3.6832e-05, Norm deltaR: 23655.3
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.298311
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 2.06382 (max: 1e-11) 	Norm deltaX: 0.000130619, Norm deltaR: 34397.7
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.299381
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.629705 (max: 1e-11) 	Norm deltaX: 6.87973e-05, Norm deltaR: 20294.1
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.300828
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 4.62386 (max: 1e-11) 	Norm deltaX: 0.000112018, Norm deltaR: 85283.4
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.300497
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.27092 (max: 1e-11) 	Norm deltaX: 5.98106e-05, Norm deltaR: 44986.7
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.292617
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.01805 (max: 1e-11) 	Norm deltaX: 4.90757e-05, Norm deltaR: 45811.5
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.297506
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 110.905 (max: 1e-11) 	Norm deltaX: 0.000383857, Norm deltaR: 586057
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.292688
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 23.5413 (max: 1e-11) 	Norm deltaX: 0.00049542, Norm deltaR: 100037
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.293867
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 16.3931 (max: 1e-11) 	Norm deltaX: 0.000290913, Norm deltaR: 119289
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.280673
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 265.53 (max: 1e-11) 	Norm deltaX: 0.00112441, Norm deltaR: 549875
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.27712
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.43946 (max: 1e-11) 	Norm deltaX: 9.10719e-05, Norm deltaR: 32120.9
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.285774
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 12.5039 (max: 1e-11) 	Norm deltaX: 0.0003554, Norm deltaR: 75775.5
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.285681
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.23567 (max: 1e-11) 	Norm deltaX: 7.6196e-05, Norm deltaR: 33692.3
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.282645
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 10.3473 (max: 1e-11) 	Norm deltaX: 0.000302727, Norm deltaR: 96458.9
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.276045
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.0779823 (max: 1e-11) 	Norm deltaX: 2.5186e-05, Norm deltaR: 6223.81
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.276494
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.0234363 (max: 1e-11) 	Norm deltaX: 1.39495e-05, Norm deltaR: 3430.67
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.280038
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.028472 (max: 1e-11) 	Norm deltaX: 1.04764e-05, Norm deltaR: 5471.45
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.0871239
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 4.34768 (max: 1e-11) 	Norm deltaX: 0.000197368, Norm deltaR: 44764.5
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.118098
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 12.7886 (max: 1e-11) 	Norm deltaX: 0.000297266, Norm deltaR: 88097.7
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.118346
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 32.0121 (max: 1e-11) 	Norm deltaX: 0.000334149, Norm deltaR: 192557
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.135677
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 59.5117 (max: 1e-11) 	Norm deltaX: 0.000318496, Norm deltaR: 390190
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.137817
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 5.2998 (max: 1e-11) 	Norm deltaX: 0.000241902, Norm deltaR: 44299
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.153931
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Success! Cyclic Pushover Analysis	 Node=3, Dof=1, Disp=5.280861725990779e-05

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ovs.plot_loads_2d(ax = ax[0])
ovs.plot_defo(ax=ax[1])
ax[0].set_title("Loads")
ax[1].set_title("Deformation")
plt.suptitle("Reverse Cyclic Pushover Analysis")
# Out:
# Text(0.5, 0.98, 'Reverse Cyclic Pushover Analysis')

# %%
disps = np.loadtxt('Outputs/fiberSection/CyclicPushover/DispFree.txt')
rxns = np.loadtxt('Outputs/fiberSection/CyclicPushover/ReactionsSupport.txt')
plt.plot(disps[:, 1]/inch, -rxns[:,1]/kip)
plt.grid()
#plt.xticks(list(range(0, 50, 5)))
#plt.xlim((0, 50))
#plt.ylim((0, 800))
plt.xlabel("Relative Lateral Displacement (inch)")
plt.ylabel("Base Shear (kip)")
plt.title("Force Deformation Response - Full Cycle Cyclic Pushover")
# Out:
# Text(0.5, 1.0, 'Force Deformation Response - Full Cycle Cyclic Pushover')

# %% [markdown]
# #### runnning 3 cycles

# %%
getModel()
getSections()
runGravityAnalysis()
getRecorders('fiberSection', 'CyclicPushover')
runReverseCyclicPushover(3)
# Out:
# 10.972821945643894 0.010972821945643894
# WARNING can't set handler after analysis is created
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 17.8381 (max: 1e-11) 	Norm deltaX: 0.000330215, Norm deltaR: 116246
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.292689
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 5.44946 (max: 1e-11) 	Norm deltaX: 0.000221844, Norm deltaR: 53351.3
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.293745
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 10.2618 (max: 1e-11) 	Norm deltaX: 0.000285298, Norm deltaR: 79762
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.29675
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 12.8508 (max: 1e-11) 	Norm deltaX: 0.000181668, Norm deltaR: 155831
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.297371
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.44546 (max: 1e-11) 	Norm deltaX: 3.4783e-05, Norm deltaR: 25980.4
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.294269
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 340.367 (max: 1e-11) 	Norm deltaX: 0.000731743, Norm deltaR: 961805
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.298534
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.977642 (max: 1e-11) 	Norm deltaX: 7.06815e-05, Norm deltaR: 29152
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.286138
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 434.477 (max: 1e-11) 	Norm deltaX: 0.00106379, Norm deltaR: 949242
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.295188
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 185.252 (max: 1e-11) 	Norm deltaX: 0.000989825, Norm deltaR: 502550
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.286767
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 9.50542 (max: 1e-11) 	Norm deltaX: 0.000220246, Norm deltaR: 90224.6
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.290741
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 84.4964 (max: 1e-11) 	Norm deltaX: 0.000699934, Norm deltaR: 250492
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.285137
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 15.3945 (max: 1e-11) 	Norm deltaX: 0.000421869, Norm deltaR: 73959.2
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.293127
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 3.39426 (max: 1e-11) 	Norm deltaX: 0.000126604, Norm deltaR: 57193.4
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.0963472
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.804381 (max: 1e-11) 	Norm deltaX: 8.26632e-05, Norm deltaR: 21142.3
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.291779
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 29.2552 (max: 1e-11) 	Norm deltaX: 0.000260956, Norm deltaR: 230735
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.292689
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 7.45454 (max: 1e-11) 	Norm deltaX: 0.000234795, Norm deltaR: 70152.2
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.291066
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 34.4747 (max: 1e-11) 	Norm deltaX: 0.000279085, Norm deltaR: 273654
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.290901
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 17.3554 (max: 1e-11) 	Norm deltaX: 0.000210857, Norm deltaR: 173437
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.288114
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 3.09064 (max: 1e-11) 	Norm deltaX: 8.42695e-05, Norm deltaR: 74229.7
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.289437
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 56.7616 (max: 1e-11) 	Norm deltaX: 0.000316414, Norm deltaR: 373599
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.288962
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 5.99049 (max: 1e-11) 	Norm deltaX: 0.000123679, Norm deltaR: 123757
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.28309
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 4.71264 (max: 1e-11) 	Norm deltaX: 0.000152033, Norm deltaR: 65503.3
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.281602
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.35621 (max: 1e-11) 	Norm deltaX: 3.26335e-05, Norm deltaR: 22438.2
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.285748
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.0128834 (max: 1e-11) 	Norm deltaX: 7.78302e-06, Norm deltaR: 3581.89
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.281361
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 35.8783 (max: 1e-11) 	Norm deltaX: 0.000251868, Norm deltaR: 286951
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.2722
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.30493 (max: 1e-11) 	Norm deltaX: 7.81613e-05, Norm deltaR: 35066
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.285788
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 6.66986 (max: 1e-11) 	Norm deltaX: 0.000243494, Norm deltaR: 77204.8
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.277933
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 7.6174 (max: 1e-11) 	Norm deltaX: 0.000271065, Norm deltaR: 56439.8
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.277308
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 46.237 (max: 1e-11) 	Norm deltaX: 0.000294545, Norm deltaR: 320519
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.279822
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.943 (max: 1e-11) 	Norm deltaX: 0.000103378, Norm deltaR: 37905.8
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.198694
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 14.0277 (max: 1e-11) 	Norm deltaX: 0.000235473, Norm deltaR: 119611
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.201214
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 3.59567 (max: 1e-11) 	Norm deltaX: 0.000145117, Norm deltaR: 49861.1
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.205802
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.937503 (max: 1e-11) 	Norm deltaX: 8.04007e-05, Norm deltaR: 23407.9
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.230288
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 9.42465 (max: 1e-11) 	Norm deltaX: 0.000203954, Norm deltaR: 95320.7
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.141401
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 27.5392 (max: 1e-11) 	Norm deltaX: 0.000324058, Norm deltaR: 173555
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.162873
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 7.38698 (max: 1e-11) 	Norm deltaX: 0.000186373, Norm deltaR: 80509.5
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.171989
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 15.9828 (max: 1e-11) 	Norm deltaX: 0.000262218, Norm deltaR: 126641
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.193607
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 7.44852 (max: 1e-11) 	Norm deltaX: 0.000161241, Norm deltaR: 92638
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.207938
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 2.6819 (max: 1e-11) 	Norm deltaX: 0.000137312, Norm deltaR: 39359.8
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.217672
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.31906 (max: 1e-11) 	Norm deltaX: 8.21168e-05, Norm deltaR: 32471.4
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.160223
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 9.16026 (max: 1e-11) 	Norm deltaX: 0.000192581, Norm deltaR: 98138
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.26113
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 12.7643 (max: 1e-11) 	Norm deltaX: 0.000195795, Norm deltaR: 133879
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.26386
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.94541 (max: 1e-11) 	Norm deltaX: 9.59182e-05, Norm deltaR: 41601.7
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.134882
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.771282 (max: 1e-11) 	Norm deltaX: 6.61239e-05, Norm deltaR: 23417.7
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.185066
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 46.3822 (max: 1e-11) 	Norm deltaX: 0.000440609, Norm deltaR: 218096
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.261993
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 37.2254 (max: 1e-11) 	Norm deltaX: 0.000481014, Norm deltaR: 187205
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.270231
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Success! Cyclic Pushover Analysis	 Node=3, Dof=1, Disp=5.280861725968054e-05

# %%
disps = np.loadtxt('Outputs/fiberSection/CyclicPushover/DispFree.txt')
rxns = np.loadtxt('Outputs/fiberSection/CyclicPushover/ReactionsSupport.txt')
plt.plot(disps[:, 1]/inch, -rxns[:,1]/kip)
plt.grid()
#plt.xticks(list(range(0, 50, 5)))
#plt.xlim((0, 50))
#plt.ylim((0, 800))
plt.xlabel("Relative Lateral Displacement (inch)")
plt.ylabel("Base Shear (kip)")
plt.title("Force Deformation Response - 3 Full Cycle Pushover")
# Out:
# Text(0.5, 1.0, 'Force Deformation Response - 3 Full Cycle Pushover')

# %% [markdown]
# # running half cycle only

# %%
getModel()
getSections(False)
runGravityAnalysis()
getRecorders('nonLinear', 'CyclicPushover')
runReverseCyclicPushover(1, 'Push')
# Out:
# 10.972821945643894 0.010972821945643894
# WARNING can't set handler after analysis is created
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 13.0591 (max: 1e-11) 	Norm deltaX: 0.000337793, Norm deltaR: 83192.5
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.292976
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.818912 (max: 1e-11) 	Norm deltaX: 6.01173e-05, Norm deltaR: 30438.8
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.300061
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 27.4073 (max: 1e-11) 	Norm deltaX: 0.000327886, Norm deltaR: 174229
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.300769
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 2.22052 (max: 1e-11) 	Norm deltaX: 0.000132421, Norm deltaR: 37076.7
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.303016
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 5.85248 (max: 1e-11) 	Norm deltaX: 0.000160974, Norm deltaR: 79562.1
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.304853
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 43.3071 (max: 1e-11) 	Norm deltaX: 0.000419213, Norm deltaR: 208610
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.299854
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 10.5604 (max: 1e-11) 	Norm deltaX: 0.000236021, Norm deltaR: 96019.3
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.29092
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 84.7682 (max: 1e-11) 	Norm deltaX: 0.000695998, Norm deltaR: 257352
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.288277
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 30.4427 (max: 1e-11) 	Norm deltaX: 0.000225704, Norm deltaR: 281994
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.290833
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 86.8371 (max: 1e-11) 	Norm deltaX: 0.000709135, Norm deltaR: 258237
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.285665
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 6.30193 (max: 1e-11) 	Norm deltaX: 0.000229971, Norm deltaR: 55359.3
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.29307
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 2.81672 (max: 1e-11) 	Norm deltaX: 0.000134662, Norm deltaR: 44617.7
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.0963792
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 14.8755 (max: 1e-11) 	Norm deltaX: 0.000245873, Norm deltaR: 130177
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.297727
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.384035 (max: 1e-11) 	Norm deltaX: 3.6832e-05, Norm deltaR: 23655.3
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.298311
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 2.06382 (max: 1e-11) 	Norm deltaX: 0.000130619, Norm deltaR: 34397.7
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.299381
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.629705 (max: 1e-11) 	Norm deltaX: 6.87973e-05, Norm deltaR: 20294.1
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.300828
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 4.62386 (max: 1e-11) 	Norm deltaX: 0.000112018, Norm deltaR: 85283.4
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.300497
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.27092 (max: 1e-11) 	Norm deltaX: 5.98106e-05, Norm deltaR: 44986.7
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.292617
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.01805 (max: 1e-11) 	Norm deltaX: 4.90757e-05, Norm deltaR: 45811.5
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.297506
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 110.905 (max: 1e-11) 	Norm deltaX: 0.000383857, Norm deltaR: 586057
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.292688
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 23.5413 (max: 1e-11) 	Norm deltaX: 0.00049542, Norm deltaR: 100037
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.293867
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 16.3931 (max: 1e-11) 	Norm deltaX: 0.000290913, Norm deltaR: 119289
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.280673
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 265.53 (max: 1e-11) 	Norm deltaX: 0.00112441, Norm deltaR: 549875
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.27712
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.43946 (max: 1e-11) 	Norm deltaX: 9.10719e-05, Norm deltaR: 32120.9
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.285774
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 12.5039 (max: 1e-11) 	Norm deltaX: 0.0003554, Norm deltaR: 75775.5
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.285681
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 1.23567 (max: 1e-11) 	Norm deltaX: 7.6196e-05, Norm deltaR: 33692.3
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.282645
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 10.3473 (max: 1e-11) 	Norm deltaX: 0.000302727, Norm deltaR: 96458.9
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.276045
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.0779823 (max: 1e-11) 	Norm deltaX: 2.5186e-05, Norm deltaR: 6223.81
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.276494
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.0234363 (max: 1e-11) 	Norm deltaX: 1.39495e-05, Norm deltaR: 3430.67
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor -0.280038
# OpenSees > analyze failed, returned: -3 error flag
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Analysis Failed ! Trying other methods ...
# Trying Newton with Initial Tangent
# Success! Cyclic Pushover Analysis	 Node=3, Dof=1, Disp=5.280861725990779e-05
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 0.028472 (max: 1e-11) 	Norm deltaX: 1.04764e-05, Norm deltaR: 5471.45
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.0871239
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 4.34768 (max: 1e-11) 	Norm deltaX: 0.000197368, Norm deltaR: 44764.5
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.118098
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 12.7886 (max: 1e-11) 	Norm deltaX: 0.000297266, Norm deltaR: 88097.7
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.118346
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 32.0121 (max: 1e-11) 	Norm deltaX: 0.000334149, Norm deltaR: 192557
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.135677
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 59.5117 (max: 1e-11) 	Norm deltaX: 0.000318496, Norm deltaR: 390190
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.137817
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestEnergyIncr::test() - failed to converge
# after: 100 iterations
#  current EnergyIncr: 5.2998 (max: 1e-11) 	Norm deltaX: 0.000241902, Norm deltaR: 44299
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 0.153931
# OpenSees > analyze failed, returned: -3 error flag

# %%
disps = np.loadtxt('Outputs/fiberSection/CyclicPushover/DispFree.txt')
rxns = np.loadtxt('Outputs/fiberSection/CyclicPushover/ReactionsSupport.txt')
plt.plot(disps[:, 1]/inch, -rxns[:,1]/kip)
plt.grid()
#plt.xticks(list(range(0, 50, 5)))
#plt.xlim((0, 50))
#plt.ylim((0, 800))
plt.xlabel("Relative Lateral Displacement (inch)")
plt.ylabel("Base Shear (kip)")
plt.title("Force Deformation Response - Full Cycle Cyclic Pushover")
# Out:
# Text(0.5, 1.0, 'Force Deformation Response - Full Cycle Cyclic Pushover')
